# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import datetime

# %config IPCompleter.greedy=True 
# %matplotlib inline

# %%
class display(object):
    """Display HTML representation of multiple objects"""
    template = """<div style="float: left; padding: 10px;">
    <p style='font-family:"Courier New", Courier, monospace'>{0}</p>{1}
    </div>"""
    def __init__(self, *args):
        self.args = args
        
    def _repr_html_(self):
        return '\n'.join(self.template.format(a, eval(a)._repr_html_())
                         for a in self.args)
    
    def __repr__(self):
        return '\n\n'.join(a + '\n' + repr(eval(a))
                           for a in self.args)

# %%
#for trend label
source_file='datasets\\Tf15M\\Data_S50F_15M_2014Now\\ML-Trend_S50F-15M_2014Now-TrainData.csv'

train_file='datasets\\Tf15M\\Train14To15_Test16To17\\Train_Trend_S50-15M_14To15.csv'

test_file='datasets\\Tf15M\\Train14To15_Test16To17\\Test_Trend_S50-15M_16To17.csv'
unlabel_file='datasets\\Tf15M\\Train14To15_Test16To17\\Unlabel_Trend_S50-15M_16To17.csv'

# %%
dfx=pd.read_csv(source_file,index_col='datetime',parse_dates =['datetime'],dayfirst=True)

print(dfx.shape)
# Out:
# (33272, 28)

# %% [markdown]
# # Create Train Data

# %%
df_train=dfx.loc['2014':'2015',:]
#df_train.info()
display('df_train.head(3)','df_train.tail(3)')
df_train.to_csv(train_file)

# %%
display('df_train.head(3)','df_train.tail(3)')
# Out:
# df_train.head(3)
#                       open   high    low  close  indy_ma-110  indy_ma-440  \
# datetime
# 2014-01-02 09:45:00  868.5  868.9  863.5  863.5       895.70       918.17
# 2014-01-02 10:00:00  864.0  864.9  862.2  863.1       895.24       918.03
# 2014-01-02 10:15:00  863.2  864.5  861.6  861.6       894.76       917.89
#
#                      indy_ma-550  indy_ema-600  indy_ma-1100  indy_hh-550  \
# datetime
# 2014-01-02 09:45:00       922.19        923.27        952.07        974.5
# 2014-01-02 10:00:00       922.01        923.07        951.95        974.5
# 2014-01-02 10:15:00       921.82        922.87        951.82        974.5
#
#                      ...  indy_rsi25-ma20  indy_6ATRTrail-110  \
# datetime             ...
# 2014-01-02 09:45:00  ...            33.26              879.62
# 2014-01-02 10:00:00  ...            33.42              879.22
# 2014-01-02 10:15:00  ...            33.68              877.73
#
# ...

# %% [markdown]
# # Creat Test & Unseen Data

# %%
labelname='TrendLabel'
colList=[col for col in dfx.columns if col!=labelname]

df_test=dfx.loc['2016':'03-2018',:]
df_unseen=dfx.loc['2016':'03-2018',colList]


#df_test.info()
#df_unseen.info()

# %%
display('df_test.head(3)','df_test.tail(3)')
# Out:
# df_test.head(3)
#                       open   high    low  close  indy_ma-110  indy_ma-440  \
# datetime
# 2016-01-04 09:45:00  785.0  787.0  782.5  785.0       797.45       822.09
# 2016-01-04 10:00:00  784.8  785.0  782.3  784.5       797.30       821.90
# 2016-01-04 10:15:00  784.5  785.5  783.4  784.4       797.16       821.71
#
#                      indy_ma-550  indy_ema-600  indy_ma-1100  indy_hh-550  \
# datetime
# 2016-01-04 09:45:00        833.2        831.44        867.28        896.0
# 2016-01-04 10:00:00        833.0        831.28        867.16        896.0
# 2016-01-04 10:15:00        832.8        831.13        867.03        896.0
#
#                      ...  indy_rsi25-ma20  indy_6ATRTrail-110  \
# datetime             ...
# 2016-01-04 09:45:00  ...            50.39              800.03
# 2016-01-04 10:00:00  ...            49.42              799.54
# 2016-01-04 10:15:00  ...            48.40              799.42
#
# ...

# %%
display('df_unseen.head(3)','df_unseen.tail(3)')
# Out:
# df_unseen.head(3)
#                       open   high    low  close  indy_ma-110  indy_ma-440  \
# datetime
# 2016-01-04 09:45:00  785.0  787.0  782.5  785.0       797.45       822.09
# 2016-01-04 10:00:00  784.8  785.0  782.3  784.5       797.30       821.90
# 2016-01-04 10:15:00  784.5  785.5  783.4  784.4       797.16       821.71
#
#                      indy_ma-550  indy_ema-600  indy_ma-1100  indy_hh-550  \
# datetime
# 2016-01-04 09:45:00        833.2        831.44        867.28        896.0
# 2016-01-04 10:00:00        833.0        831.28        867.16        896.0
# 2016-01-04 10:15:00        832.8        831.13        867.03        896.0
#
#                      ...  indy_hist_macd110-440  indy_rsi25-ma20  \
# datetime             ...
# 2016-01-04 09:45:00  ...                   2.91            50.39
# 2016-01-04 10:00:00  ...                   2.92            49.42
# 2016-01-04 10:15:00  ...                   2.94            48.40
#
# ...

# %%
df_unseen.to_csv(unlabel_file)
df_test.to_csv(test_file)
